# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
credits=pd.read_csv('../dataset/tmdb_5000_credits.csv')
movies=pd.read_csv('../dataset/tmdb_5000_movies.csv')

# %% [markdown]
# # Data Cleaning:
# 1. Credits Dataset:
#    - The **Cast and Crew feature** is a list that has a dictionary with key-value pair of the numerous characters and crew members respectively in the movie. Since it consists of a lot of characters we can only use the top 5 characters and only the director's name from the crew member since they are the one popularly recognized by audience. (Tideness)
# 3. Movies Dataset:
#    - **Home Page**: 64% of the values are missing (Completeness)
#    - **Tagline**: 17% of the values are missing (Completeness)
#    - The **Genres, Keywords, Production_companines, Production_countries** is also inside a list with key-value pairs (Tideness)

# %%
print(f'The shape of the credits dataset is {credits.shape}')
print(f'The shape of the movies dataset is {movies.shape}')
# Out:
# The shape of the credits dataset is (4803, 4)
# The shape of the movies dataset is (4803, 20)

# %%
credits.sample(5)
# Out:
#       movie_id             title  \
# 1073      8987    The River Wild
# 406      51052  Arthur Christmas
# 4645    142132        Sugar Town
# 1471     12429             Ponyo
# 4740    111794          20 Dates
#
#                                                    cast  \
# 1073  [{"cast_id": 1, "character": "Gail Hartman", "...
# 406   [{"cast_id": 2, "character": "Arthur (voice)",...
# 4645  [{"cast_id": 22, "character": "Clive", "credit...
# 1471  [{"cast_id": 14, "character": "Ponyo (voice)",...
# 4740  [{"cast_id": 1, "character": "Myles", "credit_...
#
#                                                    crew
# 1073  [{"credit_id": "52fe44cfc3a36847f80ab353", "de...
# 406   [{"credit_id": "5913a131925141580d00132d", "de...
# 4645  [{"credit_id": "52fe4acf9251416c750eeda3", "de...
# 1471  [{"credit_id": "52fe44df9251416c75043e6f", "de...
# 4740  [{"credit_id": "52fe4b02c3a36847f81ed6f9", "de...

# %%
movies.sample(3)
# Out:
#         budget                                             genres  \
# 3005  10000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 1117  44000000                      [{"id": 18, "name": "Drama"}]
# 2398  24000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                          homepage     id  \
# 3005                          NaN   9034
# 1117                          NaN  37950
# 2398  http://www.hitmanmovie.com/   1620
#
#                                                keywords original_language  \
# 3005  [{"id": 331, "name": "tattoo"}, {"id": 2570, "...                en
# 1117  [{"id": 380, "name": "brother brother relation...                en
# 2398  [{"id": 782, "name": "assassin"}, {"id": 1308,...                en
#
#           original_title                                           overview  \
# 3005  The Banger Sisters  In the late '60s, the self-proclaimed belles o...
# 1117   Charlie St. Cloud  Accomplished sailor Charlie St. Cloud has the ...
# 2398              Hitman  The best-selling videogame, Hitman, roars to l...
#
#       popularity                               production_companies  \
# 3005    6.015354   [{"name": "Fox Searchlight Pictures", "id": 43}]
# 1117   21.754330  [{"name": "Universal Pictures", "id": 33}, {"n...
# 2398   42.669304  [{"name": "Twentieth Century Fox Film Corporat...
#
#                                    production_countries release_date  \
# 3005  [{"iso_3166_1": "US", "name": "United States o...   2002-09-20
# 1117  [{"iso_3166_1": "US", "name": "United States o...   2010-05-01
# 2398  [{"iso_3166_1": "FR", "name": "France"}, {"iso...   2007-11-21
#
#        revenue  runtime                                   spoken_languages  \
# 3005         0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 1117  48190704     99.0           [{"iso_639_1": "en", "name": "English"}]
# 2398  99965753     89.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#         status                                           tagline  \
# 3005  Released  Some friendships last forever... like it or not.
# 1117  Released                               Life is for living.
# 2398  Released                                       Assassin 47
#
#                    title  vote_average  vote_count
# 3005  The Banger Sisters           5.5          62
# 1117   Charlie St. Cloud           6.8         566
# 2398              Hitman           5.9         966

# %%
credits.isnull().mean()*100
# Out:
# movie_id    0.0
# title       0.0
# cast        0.0
# crew        0.0
# dtype: float64

# %%
movies.isnull().mean()*100
# Out:
# budget                   0.000000
# genres                   0.000000
# homepage                64.355611
# id                       0.000000
# keywords                 0.000000
# original_language        0.000000
# original_title           0.000000
# overview                 0.062461
# popularity               0.000000
# production_companies     0.000000
# production_countries     0.000000
# release_date             0.020820
# revenue                  0.000000
# runtime                  0.041641
# spoken_languages         0.000000
# status                   0.000000
# tagline                 17.572351
# title                    0.000000
# vote_average             0.000000
# vote_count               0.000000
# dtype: float64

# %%
credits.duplicated().sum()
# Out:
# 0

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies=movies.merge(credits,on="title")
movies.shape
# Out:
# (4809, 23)

# %%
pd.set_option('display.max_columns', None)
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title  vote_average  vote_count  movie_id  \
# 0  Enter the World of Pandora.  Avatar           7.2       11800     19995
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %% [markdown]
# Since I am focusing on making a content-based reccommendation system not all 23 columns is going to be useful. Thus, my goal is to just extract keywords that can help me reccommend a particular user. The columns that I will be using are: **Genres, id, keywords, overview, title, cast, crew**

# %%
movies=movies[['genres','id','keywords','overview','cast','crew','title']]

# %%
movies.sample(2)
# Out:
#                                                  genres     id  \
# 3062  [{"id": 16, "name": "Animation"}, {"id": 18, "...  24034
# 1996                      [{"id": 18, "name": "Drama"}]  10316
#
#                                                keywords  \
# 3062                                                 []
# 1996  [{"id": 2494, "name": "ohio"}, {"id": 6078, "n...
#
#                                                overview  \
# 3062  Spot (Lane) is a dog who can talk and read. Po...
# 1996  Dirty tricks stand to soil an ambitious young ...
#
#                                                    cast  \
# 3062  [{"cast_id": 2, "character": "Spot Helperman /...
# 1996  [{"cast_id": 6, "character": "Stephen Meyers",...
#
#                                                    crew              title
# 3062  [{"credit_id": "59b1da12925141079d08c8a4", "de...      Teacher's Pet
# 1996  [{"credit_id": "52fe43589251416c7500ccbb", "de...  The Ides of March

# %%
movies.isnull().mean()*100
# Out:
# genres      0.000000
# id          0.000000
# keywords    0.000000
# overview    0.062383
# cast        0.000000
# crew        0.000000
# title       0.000000
# dtype: float64

# %%
movies.dropna(inplace=True)

# %% [markdown]
# # Data Preprocessing:

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
def extractName(object):
    list=[]
    for keys in ast.literal_eval(object):
        if "name" in keys:
            list.append(keys["name"])
    return list

# %%
movies.genres=movies.genres.apply(extractName)

# %%
movies.iloc[0].genres
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
movies.iloc[0].keywords
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies.keywords=movies.keywords.apply(extractName)

# %%
def actor_name(object):
    list=[]
    count=0
    for keys in ast.literal_eval(object):
        if count<5:
            if "name" in keys:
                list.append(keys["name"])
                count+=1
    return list

# %%
movies.cast=movies.cast.apply(actor_name)

# %%
movies.iloc[0].cast
# Out:
# ['Sam Worthington',
#  'Zoe Saldana',
#  'Sigourney Weaver',
#  'Stephen Lang',
#  'Michelle Rodriguez']

# %%
def director(object):
    list=[]
    for keys in ast.literal_eval(object):
        if keys['job']=='Director':
            list.append(keys['name'])
    return list

# %%
movies.crew=movies.crew.apply(director)

# %%
movies.iloc[0].crew
# Out:
# ['James Cameron']

# %%
movies.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                                 cast                 crew  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...      [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...     [Gore Verbinski]
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...         [Sam Mendes]
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  [Christopher Nolan]
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...     [Andrew Stanton]
#
#                                       title
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter

# %%
movies.overview=movies.overview.apply(lambda x:x.split())

# %%
def remove_space(object):
    list=[]
    for items in object:
        list.append(items.replace(" ",""))
    return list

# %%
movies.cast=movies.cast.apply(remove_space)
movies.crew=movies.crew.apply(remove_space)
movies.genres=movies.genres.apply(remove_space)
movies.keywords=movies.keywords.apply(remove_space)

# %%
movies.head(2)
# Out:
#                                          genres     id  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]  19995
# 1                  [Adventure, Fantasy, Action]    285
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                                 cast             crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...   [JamesCameron]
# 1  [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...  [GoreVerbinski]
#
#                                       title
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End

# %% [markdown]
# # EDA:

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4806 non-null   object
#  1   id        4806 non-null   int64
#  2   keywords  4806 non-null   object
#  3   overview  4806 non-null   object
#  4   cast      4806 non-null   object
#  5   crew      4806 non-null   object
#  6   title     4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 300.4+ KB

# %%
from collections import Counter
import itertools

# %%
all_genres=list(itertools.chain.from_iterable(movies.genres))
genre_counts=Counter(all_genres)

# %%
plt.bar(genre_counts.keys(),genre_counts.values(),color='red')
plt.xticks(rotation=90)
plt.title('Genres Distribution')
plt.show()

# %% [markdown]
# We can see that Drama genres are more popular among users.

# %%
all_cast=list(itertools.chain.from_iterable(movies.cast))
cast_counts=Counter(all_cast)
print(cast_counts.most_common(10))
# Out:
# [('RobertDeNiro', 54), ('SamuelL.Jackson', 44), ('BruceWillis', 39), ('MattDamon', 36), ('NicolasCage', 35), ('MorganFreeman', 35), ('JohnnyDepp', 32), ('BradPitt', 32), ('MarkWahlberg', 31), ('OwenWilson', 31)]

# %%
top_ten_actors=cast_counts.most_common(10)
names=[cast[0] for cast in top_ten_actors]
counts=[cast[1] for cast in top_ten_actors]

sns.barplot(x=counts,y=names)
plt.title('Top 10 most frequent actors')
plt.show()

# %% [markdown]
# We can see that Robert De Niro has appeared in more than 50 plus movies.

# %%
from wordcloud import WordCloud

# %%
all_overviews= ' '.join([' '.join(overview) for overview in movies['overview']])

# %%
wordcloud = WordCloud(width=800, height=400).generate(all_overviews)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Here, we can visulalize that the most frequent words in overview are find,family,world and life.

# %%
movies['tags']=movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']

# %%
new_movies=movies[['id','title','tags']]

# %%
new_movies.tags=new_movies.tags.apply(lambda x:" ".join(x)) #Converting the list tag to strings
# Out:
# C:\Users\khadk\AppData\Local\Temp\ipykernel_17260\258781245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies.tags=new_movies.tags.apply(lambda x:" ".join(x)) #Converting the list tag to strings

# %%
new_movies.tags=new_movies.tags.apply(lambda x:x.lower()) #Lowercasing all the letters in the tags
# Out:
# C:\Users\khadk\AppData\Local\Temp\ipykernel_17260\2938155806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies.tags=new_movies.tags.apply(lambda x:x.lower()) #Lowercasing all the letters in the tags

# %%
new_movies.sample(3)
# Out:
#          id              title  \
# 4292  46256  The Lion of Judah
# 982   13498   Man of the House
# 1775  16617        Mindhunters
#
#                                                    tags
# 4292  upon learning that judah has been trapped in t...
# 982   texas ranger roland sharp is assigned to prote...
# 1775  trainees in the fbi's psychological profiling ...

# %% [markdown]
# #Vectorization

# %%
from nltk.stem import SnowballStemmer
snow_ball=SnowballStemmer('english')

# %%
#Stemming the root words using snowball stemmer
def stem(text):
    new_text=[]
    for word in text.split():
        new_text.append(snow_ball.stem(word))

    return " ".join(new_text)

# %%
new_movies['tags']=new_movies['tags'].apply(stem)
# Out:
# C:\Users\khadk\AppData\Local\Temp\ipykernel_17260\2598606076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_movies['tags']=new_movies['tags'].apply(stem)

# %%
new_movies.head(1)
# Out:
#       id   title                                               tags
# 0  19995  Avatar  in the 22nd century, a parapleg marin is dispa...

# %% [markdown]
# #Text Vectorization:

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
#Extracting 5000 most common words for vetorization:
vectors=cv.fit_transform(new_movies['tags']).toarray()

# %%
vectors.shape
# Out:
# (4806, 5000)

# %%
features_name=cv.get_feature_names_out()

# %%
print(features_name)
# Out:
# ['000' '007' '10' ... 'zone' 'zoo' 'zooeydeschanel']

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)

# %%
cosine_similarity(vectors).shape
# Out:
# (4806, 4806)

# %%
similarity[2]
# Out:
# array([0.08471737, 0.05802589, 1.        , ..., 0.0246183 , 0.        ,
#        0.        ])
